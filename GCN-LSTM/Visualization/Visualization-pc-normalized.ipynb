# %%
import os
import pickle
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
results_folder = r'C:\Users\Mahender\Documents\MS docs\Final docs\Rowan University\Research_project\GCN neighborhood\saved_pc_results'

# %%
def load_all_pkl_files(folder_path):
    # Dictionary to store the loaded data
    all_models_results = {}

    # List all files in the folder
    for filename in os.listdir(folder_path):
        # Check if the file is a .pkl file
        if filename.endswith('.pkl'):
            # Full path to the file
            file_path = os.path.join(folder_path, filename)
            
            # Load the .pkl file
            with open(file_path, 'rb') as file:
                model_results = pickle.load(file)
            
            # Use the filename (without extension) as the key in the dictionary
            model_name = os.path.splitext(filename)[0]
            all_models_results[model_name] = model_results
    
    return all_models_results

# %%
all_models_results = load_all_pkl_files(results_folder)

# %%
all_models_results.keys()
# Out:
# dict_keys(['base_add_1', 'base_mean_1', 'MLv1_add_1', 'MLv1_mean_1', 'MLv2_add_1', 'MLv2_mean_1', 'MLv3_mul_1'])

# %%
all_models_results['base_add_1'].keys()
# Out:
# dict_keys(['model', 'aggregation', 'game', 'true_influences_all_samples', 'predicted_influences_all_samples', 'residue_all_samples', 'mean_residue_per_player', 'average_residue_all_players', 'median_residue_per_player'])

# %%
plt.figure(figsize=(14, 6))
players = np.arange(1, 23)

max_val = 0
for model_name in all_models_results.keys():
    median_residue_per_player = all_models_results[model_name]['median_residue_per_player']
    plt.plot(players, median_residue_per_player, 'o-',  label=model_name)
    if np.max(median_residue_per_player) > max_val:
        max_val = np.max(median_residue_per_player)

plt.xlabel('Player')
plt.ylabel('Median Residue')
plt.xticks(players)
plt.yticks(np.arange(0, max_val + 0.1, 0.1))  # Set y-ticks at 0.1 intervals
plt.title('Median Residue per player Across Different Models')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(14, 6))
players = np.arange(1, 23)

max_val = 0
for model_name in all_models_results.keys():
    median_residue_per_player = all_models_results[model_name]['median_residue_per_player']
    if all_models_results[model_name]['game'] == 2:
        plt.plot(players, median_residue_per_player, 'o-',  label=model_name)
        if np.max(median_residue_per_player) > max_val:
            max_val = np.max(median_residue_per_player)

plt.xlabel('Player')
plt.ylabel('Median Residue')
plt.xticks(players)
plt.yticks(np.arange(0, max_val + 0.1, 0.1))  # Set y-ticks at 0.1 intervals
plt.title('Median Residue per player Across Different Models Game 2')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.figure(figsize=(14, 6))
players = np.arange(1, 23)

max_val = 0
for model_name in all_models_results.keys():
    median_residue_per_player = all_models_results[model_name]['median_residue_per_player']
    if  all_models_results[model_name]['game'] == 1:
        plt.plot(players, median_residue_per_player, 'o-',  label=model_name)
        if np.max(median_residue_per_player) > max_val:
            max_val = np.max(median_residue_per_player)

plt.xlabel('Player', fontsize=16)
plt.ylabel('Median Absolute Residual Error', fontsize=16)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xticks(players)
plt.yticks(np.arange(0, max_val + 0.1, 0.1))  # Set y-ticks at 0.1 intervals
# plt.title('Median Residue per player Across Different Models Game 1')
plt.legend(fontsize=12)
plt.show()

# %%
plt.figure(figsize=(14, 6))
players = np.arange(1, 23)

max_val = 0
for model_name in all_models_results.keys():
#     if all_models_results[model_name]['aggregation'] == 'add' and all_models_results[model_name]['model'] in ['base','MLv1']:
    if all_models_results[model_name]['model'] in ['base','MLv1'] and all_models_results[model_name]['game'] == 2:
        median_residue_per_player = all_models_results[model_name]['median_residue_per_player']
        plt.plot(players, median_residue_per_player, 'o-',  label=model_name)
        if np.max(median_residue_per_player) > max_val:
            max_val = np.max(median_residue_per_player)

plt.xlabel('Player')
plt.ylabel('Median Residue')
plt.xticks(players)
plt.yticks(np.arange(0, max_val + 0.1, 0.1))  # Set y-ticks at 0.1 intervals
plt.title('Median Residue per player with and without MI Game 2')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.figure(figsize=(14, 6))
players = np.arange(1, 23)

max_val = 0
for model_name in all_models_results.keys():
#     if all_models_results[model_name]['aggregation'] == 'add' and all_models_results[model_name]['model'] in ['base','MLv1']:
    if all_models_results[model_name]['model'] in ['base','MLv1'] and all_models_results[model_name]['game'] == 1:
        median_residue_per_player = all_models_results[model_name]['median_residue_per_player']
        plt.plot(players, median_residue_per_player, 'o-',  label=model_name)
        if np.max(median_residue_per_player) > max_val:
            max_val = np.max(median_residue_per_player)

plt.xlabel('Player')
plt.ylabel('Median Residue')
plt.xticks(players)
plt.yticks(np.arange(0, max_val + 0.1, 0.1))  # Set y-ticks at 0.1 intervals
plt.title('Median Residue per player with and without MI Game 1')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(14, 6))
players = np.arange(1, 23)

max_val = 0
for model_name in all_models_results.keys():
#     if all_models_results[model_name]['aggregation'] == 'add' and all_models_results[model_name]['model'] in ['base','MLv1']:
    if all_models_results[model_name]['model'][:2] == 'ML' and all_models_results[model_name]['aggregation'] == 'add' and all_models_results[model_name]['game'] == 2:
        median_residue_per_player = all_models_results[model_name]['median_residue_per_player']
        plt.plot(players, median_residue_per_player, 'o-',  label=model_name)
        if np.max(median_residue_per_player) > max_val:
            max_val = np.max(median_residue_per_player)

plt.xlabel('Player')
plt.ylabel('Median Residue')
plt.xticks(players)
plt.yticks(np.arange(0, max_val + 0.1, 0.1))  # Set y-ticks at 0.1 intervals
plt.title('Median Residue per player for different MI versions Game 2')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.figure(figsize=(14, 6))
players = np.arange(1, 23)

max_val = 0
for model_name in all_models_results.keys():
#     if all_models_results[model_name]['aggregation'] == 'add' and all_models_results[model_name]['model'] in ['base','MLv1']:
    if all_models_results[model_name]['model'][:2] == 'ML' and all_models_results[model_name]['aggregation'] == 'add' and all_models_results[model_name]['game'] == 1:
        median_residue_per_player = all_models_results[model_name]['median_residue_per_player']
        plt.plot(players, median_residue_per_player, 'o-',  label=model_name)
        if np.max(median_residue_per_player) > max_val:
            max_val = np.max(median_residue_per_player)

plt.xlabel('Player')
plt.ylabel('Median Residue')
plt.xticks(players)
plt.yticks(np.arange(0, max_val + 0.1, 0.1))  # Set y-ticks at 0.1 intervals
plt.title('Median Residue per player for different MI versions Game 1')
plt.legend()
plt.show()

# %%
model_names = list(all_models_results.keys())
average_residue_all_players = [all_models_results[model_name]['average_residue_all_players'] for model_name in all_models_results.keys()]

# Sort the model names and average residues by average residue
sorted_pairs = sorted(zip(average_residue_all_players, model_names))
average_residue_all_players, model_names = zip(*sorted_pairs)

model_names = [model[:-2] for model in model_names]

# Plot the average residues as a horizontal bar chart
plt.figure(figsize=(10, 6))
plt.barh(model_names, average_residue_all_players, color='skyblue')
plt.xlabel('Average Absolute Residual Error', fontsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
# plt.title('Average Residue for All Players Across Different Models')
plt.show()

# %%
# Extract game results based on the 'model', 'aggregation', and 'game' parameters
game1_results = {}
game2_results = {}
game3_results = {}

for file_name, results in all_models_results.items():
    model_name = f"{results['model']}_{results['aggregation']}"
    game = results['game']
    if game == 1:
        game1_results[model_name] = results['average_residue_all_players']
    elif game == 2:
        game2_results[model_name] = results['average_residue_all_players']
    elif game == 3:
        game3_results[model_name] = results['average_residue_all_players']

# Ensure all games have the same models
common_models = set(game1_results.keys()).intersection(game2_results.keys()).intersection(game3_results.keys())

# Create a DataFrame with the results
df = pd.DataFrame({
    'Model': list(common_models),
    'Game 1': [game1_results[model_name] for model_name in common_models],
    'Game 2': [game2_results[model_name] for model_name in common_models],
    'Game 3': [game3_results[model_name] for model_name in common_models]
})

df.set_index('Model', inplace=True)
df = df.sort_index()

# Display the DataFrame
df
# Out:
# Empty DataFrame
# Columns: [Game 1, Game 2, Game 3]
# Index: []

# %%
models_str = ', '.join(df.columns) + ' combined'

# Calculate the overall average
df['Overall Average'] = df.mean(axis=1)

# Sort the dataframe based on the overall average
df_sorted = df.sort_values(by='Overall Average')

# Plot the horizontal bar chart
plt.figure(figsize=(10, 6))
plt.barh(df_sorted.index, df_sorted['Overall Average'], color='skyblue')
plt.xlabel('Overall Average Residue')
plt.title('Average Residue for All Players Across Different Models '+ models_str)
plt.show()

# %%
np.mean(all_models_results['base_add_1']['median_residue_per_player'])
# Out:
# 0.5846201

# %%
all_models_results['base_mean_1']['median_residue_per_player'].mean()
# Out:
# 0.63705677

# %%
model_names = list(all_models_results.keys())
average_median_residue_all_players = [all_models_results[model_name]['median_residue_per_player'].mean() for model_name in all_models_results.keys()]

# Sort the model names and average residues by average residue
sorted_pairs = sorted(zip(average_median_residue_all_players, model_names))
average_median_residue_all_players, model_names = zip(*sorted_pairs)

model_names = [model[:-2] for model in model_names]

# Plot the average residues as a horizontal bar chart
plt.figure(figsize=(10, 6))
plt.barh(model_names, average_median_residue_all_players, color='skyblue')
plt.xlabel('Median Absolute Residual Error', fontsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
# plt.title('Average of Median Residue for All Players Across Different Models')
plt.show()

# %%
# Extract game results based on the 'model', 'aggregation', and 'game' parameters
game1_results = {}
game2_results = {}
game3_results = {}

for file_name, results in all_models_results.items():
    model_name = f"{results['model']}_{results['aggregation']}"
    game = results['game']
    if game == 1:
        game1_results[model_name] = results['median_residue_per_player'].mean()
    elif game == 2:
        game2_results[model_name] = results['median_residue_per_player'].mean()
    elif game == 3:
        game3_results[model_name] = results['median_residue_per_player'].mean()

# Ensure all games have the same models
common_models = set(game1_results.keys()).intersection(game2_results.keys()).intersection(game3_results.keys())

# Create a DataFrame with the results
df_median = pd.DataFrame({
    'Model': list(common_models),
    'Game 1': [game1_results[model_name] for model_name in common_models],
    'Game 2': [game2_results[model_name] for model_name in common_models],
    'Game 3': [game3_results[model_name] for model_name in common_models]
})

df_median.set_index('Model', inplace=True)
df_median = df_median.sort_index()

# Display the DataFrame
df_median
# Out:
# Empty DataFrame
# Columns: [Game 1, Game 2, Game 3]
# Index: []

# %%
models_str = ', '.join(df_median.columns) + ' combined'

# Calculate the overall average
df_median['Overall Average'] = df_median.mean(axis=1)

# Sort the dataframe based on the overall average
df_sorted = df_median.sort_values(by='Overall Average')

# Plot the horizontal bar chart
plt.figure(figsize=(10, 6))
plt.barh(df_sorted.index, df_sorted['Overall Average'], color='skyblue')
plt.xlabel('Overall Average Residue')
plt.title('Average of Median Residue for All Players Across Different Models '+ models_str)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Function to calculate mean and std for each game
def calculate_mean_std(all_models_results):
    game_results = {1: {}, 2: {}, 3: {}}
    
    for model_name, results in all_models_results.items():
        game = results['game']
        residue_all_samples = results['residue_all_samples']
        mean_residue = np.mean(residue_all_samples)
        std_residue = np.std(residue_all_samples)
        
        model_key = f"{results['model']}_{results['aggregation']}"
        game_results[game][model_key] = {
            'mean': mean_residue,
            'std': std_residue
        }
    
    return game_results

# Calculate mean and std for each game
game_results = calculate_mean_std(all_models_results)

# Ensure all games have the same models
common_models = set(game_results[1].keys()).intersection(game_results[2].keys()).intersection(game_results[3].keys())

# Create a DataFrame with the results and standard deviations
df = pd.DataFrame({
    'Model': list(common_models),
    'Game 1 Mean': [game_results[1][model_name]['mean'] for model_name in common_models],
    'Game 1 Std': [game_results[1][model_name]['std'] for model_name in common_models],
    'Game 2 Mean': [game_results[2][model_name]['mean'] for model_name in common_models],
    'Game 2 Std': [game_results[2][model_name]['std'] for model_name in common_models],
    'Game 3 Mean': [game_results[3][model_name]['mean'] for model_name in common_models],
    'Game 3 Std': [game_results[3][model_name]['std'] for model_name in common_models]
})

df.set_index('Model', inplace=True)
df = df.sort_index()

# Plot the multibar horizontal bar chart with error bars
fig, ax = plt.subplots(figsize=(12, 8))

bar_width = 0.25
index = np.arange(len(df))

# Plot Game 1
ax.barh(index, df['Game 1 Mean'], bar_width, xerr=df['Game 1 Std'], label='Game 1', color='skyblue', capsize=5)
# Plot Game 2
ax.barh(index + bar_width, df['Game 2 Mean'], bar_width, xerr=df['Game 2 Std'], label='Game 2', color='lightgreen', capsize=5)
# Plot Game 3
ax.barh(index + 2 * bar_width, df['Game 3 Mean'], bar_width, xerr=df['Game 3 Std'], label='Game 3', color='salmon', capsize=5)

# Add labels and title
ax.set_xlabel('Mean Residue')
ax.set_title('Mean Residue for Different Models with Error Bars')
ax.set_yticks(index + bar_width)
ax.set_yticklabels(df.index)
ax.legend()

plt.show()

df
# Out:
# Empty DataFrame
# Columns: [Game 1 Mean, Game 1 Std, Game 2 Mean, Game 2 Std, Game 3 Mean, Game 3 Std]
# Index: []

# %%
# Function to calculate mean for each game
def calculate_mean(all_models_results):
    game_results = {1: {}, 2: {}, 3: {}}
    
    for model_name, results in all_models_results.items():
        game = results['game']
        residue_all_samples = results['residue_all_samples']
        mean_residue = np.mean(residue_all_samples)
        
        model_key = f"{results['model']}_{results['aggregation']}"
        game_results[game][model_key] = mean_residue
    
    return game_results

# Calculate mean for each game
game_results = calculate_mean(all_models_results)

# Ensure all games have the same models
common_models = set(game_results[1].keys()).intersection(game_results[2].keys()).intersection(game_results[3].keys())

# Create a DataFrame with the results
df = pd.DataFrame({
    'Model': list(common_models),
    'Game 1 Mean': [game_results[1][model_name] for model_name in common_models],
    'Game 2 Mean': [game_results[2][model_name] for model_name in common_models],
    'Game 3 Mean': [game_results[3][model_name] for model_name in common_models]
})

df.set_index('Model', inplace=True)
df = df.sort_index()

# Plot the multibar horizontal bar chart without error bars
fig, ax = plt.subplots(figsize=(12, 8))

bar_width = 0.25
index = np.arange(len(df))

# Plot Game 1
ax.barh(index, df['Game 1 Mean'], bar_width, label='Game 1', color='skyblue')
# Plot Game 2
ax.barh(index + bar_width, df['Game 2 Mean'], bar_width, label='Game 2', color='lightgreen')
# Plot Game 3
ax.barh(index + 2 * bar_width, df['Game 3 Mean'], bar_width, label='Game 3', color='salmon')

# Add labels and title
ax.set_xlabel('Mean Residue')
ax.set_title('Mean Residue for Different Models')
ax.set_yticks(index + bar_width)
ax.set_yticklabels(df.index)
ax.legend()

plt.show()

# %%
# Function to calculate mean for each game
def calculate_mean(all_models_results):
    game_results = {1: {}, 2: {}, 3: {}}
    
    for model_name, results in all_models_results.items():
        game = results['game']
        residue_all_samples = results['residue_all_samples']
        mean_residue = np.mean(residue_all_samples)
        
        model_key = f"{results['model']}_{results['aggregation']}"
        game_results[game][model_key] = mean_residue
    
    return game_results

# Calculate mean for each game
game_results = calculate_mean(all_models_results)

# Ensure all games have the same models
common_models = set(game_results[1].keys()).intersection(game_results[2].keys()).intersection(game_results[3].keys())

# Create a DataFrame with the results
df = pd.DataFrame({
    'Model': list(common_models),
    'Game 1 Mean': [game_results[1][model_name] for model_name in common_models],
    'Game 2 Mean': [game_results[2][model_name] for model_name in common_models],
    'Game 3 Mean': [game_results[3][model_name] for model_name in common_models]
})

df.set_index('Model', inplace=True)
df = df.sort_index()

# Calculate the overall average and standard deviation across different games for each model
df['Overall Mean'] = df[['Game 1 Mean', 'Game 2 Mean', 'Game 3 Mean']].mean(axis=1)
df['Overall Std'] = df[['Game 1 Mean', 'Game 2 Mean', 'Game 3 Mean']].std(axis=1)

# Plot the combined bar chart with error bars
plt.figure(figsize=(12, 8))
plt.barh(df.index, df['Overall Mean'], xerr=df['Overall Std'], color='skyblue', ecolor='black', capsize=5)
plt.xlabel('Average Absolute Residual Error', fontsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
# plt.title('Overall Mean Residue for Different Models with Error Bars')
plt.show()

df
# Out:
# Empty DataFrame
# Columns: [Game 1 Mean, Game 2 Mean, Game 3 Mean, Overall Mean, Overall Std]
# Index: []

# %%
# Function to calculate median for each game
def calculate_median(all_models_results):
    game_results = {1: {}, 2: {}, 3: {}}
    
    for model_name, results in all_models_results.items():
        game = results['game']
        residue_all_samples = results['residue_all_samples']
        median_residue = np.median(residue_all_samples)
        
        model_key = f"{results['model']}_{results['aggregation']}"
        game_results[game][model_key] = median_residue
    
    return game_results

# Calculate median for each game
game_results = calculate_median(all_models_results)

# Ensure all games have the same models
common_models = set(game_results[1].keys()).intersection(game_results[2].keys()).intersection(game_results[3].keys())

# Create a DataFrame with the results
df = pd.DataFrame({
    'Model': list(common_models),
    'Game 1 Median': [game_results[1][model_name] for model_name in common_models],
    'Game 2 Median': [game_results[2][model_name] for model_name in common_models],
    'Game 3 Median': [game_results[3][model_name] for model_name in common_models]
})

df.set_index('Model', inplace=True)
df = df.sort_index()

# Plot the multibar horizontal bar chart without error bars
fig, ax = plt.subplots(figsize=(12, 8))

bar_width = 0.25
index = np.arange(len(df))

# Plot Game 1
ax.barh(index, df['Game 1 Median'], bar_width, label='Game 1', color='skyblue')
# Plot Game 2
ax.barh(index + bar_width, df['Game 2 Median'], bar_width, label='Game 2', color='lightgreen')
# Plot Game 3
ax.barh(index + 2 * bar_width, df['Game 3 Median'], bar_width, label='Game 3', color='salmon')

# Add labels and title
ax.set_xlabel('Median Absolute Residual Error', fontsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
ax.set_yticks(index + bar_width)
ax.set_yticklabels(df.index)
ax.legend(fontsize=12)

plt.show()

# %%
# Function to calculate median for each game
def calculate_median(all_models_results):
    game_results = {1: {}, 2: {}, 3: {}}
    
    for model_name, results in all_models_results.items():
        game = results['game']
        residue_all_samples = results['residue_all_samples']
        median_residue = np.median(residue_all_samples)
        
        model_key = f"{results['model']}_{results['aggregation']}"
        game_results[game][model_key] = median_residue
    
    return game_results

# Calculate median for each game
game_results = calculate_median(all_models_results)

# Ensure all games have the same models
common_models = set(game_results[1].keys()).intersection(game_results[2].keys()).intersection(game_results[3].keys())

# Create a DataFrame with the results
df = pd.DataFrame({
    'Model': list(common_models),
    'Game 1 Median': [game_results[1][model_name] for model_name in common_models],
    'Game 2 Median': [game_results[2][model_name] for model_name in common_models],
    'Game 3 Median': [game_results[3][model_name] for model_name in common_models]
})

df.set_index('Model', inplace=True)
df = df.sort_index()

# Calculate the overall median and standard deviation of the medians across different games for each model
df['Overall Median'] = df[['Game 1 Median', 'Game 2 Median', 'Game 3 Median']].median(axis=1)
df['Overall Std'] = df[['Game 1 Median', 'Game 2 Median', 'Game 3 Median']].std(axis=1)

# Plot the combined bar chart with error bars
plt.figure(figsize=(12, 8))
plt.barh(df.index, df['Overall Median'], xerr=df['Overall Std'], color='skyblue', ecolor='black', capsize=5)
plt.xlabel('Overall Median Residue')
plt.title('Overall Median Residue for Different Models with Error Bars')
plt.show()

df
# Out:
# Empty DataFrame
# Columns: [Game 1 Median, Game 2 Median, Game 3 Median, Overall Median, Overall Std]
# Index: []

# %%
# paper reference for gcn+lstm
# complete dataset 3 and version 3
# overall avg with game 1 and 2 combined`
# averagea of medians separate and game 1 and 2 combined
# table with average of medians similar to overall avg
# graph of soccer field with players for time frame eg 100 and 110 without title

# %%
# normalize after prediction (min-max)
# upload images to overleaf
#

# %%
all_models_results.keys()
# Out:
# dict_keys(['base_add_1', 'base_mean_1', 'MLv1_add_1', 'MLv1_mean_1', 'MLv2_add_1', 'MLv2_mean_1', 'MLv3_mul_1'])

# %%
# all_models_results['MLv4_mean_1']['aggregation']

# %%
all_models_results['base_add_2'].keys()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [31], line 1
# ----> 1 all_models_results['base_add_2'].keys()
#
# KeyError: 'base_add_2'

# %%
all_models_results['base_add_2']['true_influences_all_samples'].shape

# %%
all_models_results['base_add_2']['predicted_influences_all_samples'].shape

# %%
all_models_results['base_add_2']['true_influences_all_samples'].min(), all_models_results['base_add_2']['true_influences_all_samples'].max()

# %%
for model in all_models_results.keys():
    print(model)
    print(all_models_results[model]['predicted_influences_all_samples'].min(), all_models_results[model]['predicted_influences_all_samples'].max())

# %%
# Function to normalize predictions
def min_max_normalize(array):
    min_val = array.min()
    max_val = array.max()
    return (array - min_val) / (max_val - min_val)

# Normalize predictions for each model in all_models_results
for model in all_models_results.keys():
    predictions = all_models_results[model]['predicted_influences_all_samples']
    normalized_predictions = min_max_normalize(predictions)
    all_models_results[model]['normalized_predicted_influences'] = normalized_predictions
    print(f"Model: {model}")
    print(f"Original min: {predictions.min()}, Original max: {predictions.max()}")
    print(f"Normalized min: {normalized_predictions.min()}, Normalized max: {normalized_predictions.max()}")

# %%
# Function to calculate residue
def calculate_residue(true, pred, epsilon=1e-10):
    residue = np.abs(true - pred) / (true + epsilon)
    residue[true == 0] = 0
    return residue

# Function to calculate mean residue per player
def mean_residue_per_player(residue):
    return np.mean(residue, axis=(0, 1))

# Function to calculate average residue all players
def average_residue_all_players(mean_residue):
    return np.mean(mean_residue)

# Function to calculate median residue per player
def median_residue_per_player(residue):
    return np.median(residue, axis=(0, 1))

# Process each model
for model in all_models_results.keys():
    true_influences = all_models_results[model]['true_influences_all_samples']
    normalized_pred_influences = all_models_results[model]['normalized_predicted_influences']
    
    # Calculate residues
    residue_all_samples = calculate_residue(true_influences, normalized_pred_influences)
    mean_residue = mean_residue_per_player(residue_all_samples)
    avg_residue_all_players = average_residue_all_players(mean_residue)
    median_residue = median_residue_per_player(residue_all_samples)
    
    # Store the calculated values
    all_models_results[model]['residue_all_samples_normalized'] = residue_all_samples
    all_models_results[model]['mean_residue_per_player_normalized'] = mean_residue
    all_models_results[model]['average_residue_all_players_normalized'] = avg_residue_all_players
    all_models_results[model]['median_residue_per_player_normalized'] = median_residue

example_model = 'base_add_2'
print("Residue All Samples Normalized:", all_models_results[example_model]['residue_all_samples_normalized'])
print("Mean Residue Per Player Normalized:", all_models_results[example_model]['mean_residue_per_player_normalized'])
print("Average Residue All Players Normalized:", all_models_results[example_model]['average_residue_all_players_normalized'])
print("Median Residue Per Player Normalized:", all_models_results[example_model]['median_residue_per_player_normalized'])

# %%
plt.figure(figsize=(14, 6))
players = np.arange(1, 23)

max_val = 0
for model_name in all_models_results.keys():
    median_residue_per_player = all_models_results[model_name]['median_residue_per_player_normalized']
    plt.plot(players, median_residue_per_player, 'o-',  label=model_name)
    if np.max(median_residue_per_player) > max_val:
        max_val = np.max(median_residue_per_player)

plt.xlabel('Player')
plt.ylabel('Median Residue')
plt.xticks(players)
# plt.yticks(np.arange(0, max_val + 0.1, 0.1))  # Set y-ticks at 0.1 intervals
plt.title('Median Residue per player Across Different Models')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(14, 6))
players = np.arange(1, 23)

max_val = 0
for model_name in all_models_results.keys():
    median_residue_per_player = all_models_results[model_name]['median_residue_per_player_normalized']
    if all_models_results[model_name]['game'] == 2:
        plt.plot(players, median_residue_per_player, 'o-',  label=model_name)
        if np.max(median_residue_per_player) > max_val:
            max_val = np.max(median_residue_per_player)

plt.xlabel('Player')
plt.ylabel('Median Residue')
plt.xticks(players)
# plt.yticks(np.arange(0, max_val + 0.1, 0.1))  # Set y-ticks at 0.1 intervals
plt.title('Median Residue per player Across Different Models Game 2')
plt.legend()
plt.show()

# %%
for model in all_models_results.keys():
    residue = all_models_results[model]['residue_all_samples']
    residue_normalized = all_models_results[model]['residue_all_samples_normalized']
    
    # Calculate mean residue over all players for simplicity in plotting
    mean_residue = np.mean(residue, axis=(1, 2))
    mean_residue_normalized = np.mean(residue_normalized, axis=(1, 2))
    
    plt.figure(figsize=(10, 6))
    plt.plot(mean_residue, label='Original Residue')
    plt.plot(mean_residue_normalized, label='Normalized Residue')
    plt.xlabel('Samples')
    plt.ylabel('Mean Residue')
    plt.title(f'Residue Comparison for {model}')
    plt.legend()
    plt.show()

# %%
for model in all_models_results.keys():
    true_influences = all_models_results[model]['true_influences_all_samples']
    original_predicted = all_models_results[model]['predicted_influences_all_samples']
    normalized_predicted = all_models_results[model]['normalized_predicted_influences']
    
    # For simplicity, let's plot the first sample
    sample_idx = 0
    
    plt.figure(figsize=(12, 6))
    plt.plot(true_influences[sample_idx].flatten(), label='True Influences', color='blue')
    plt.plot(original_predicted[sample_idx].flatten(), label='Original Predicted Influences', color='orange')
    plt.plot(normalized_predicted[sample_idx].flatten(), label='Normalized Predicted Influences', color='green')
    plt.xlabel('Players')
    plt.ylabel('Influence')
    plt.title(f'True vs. Predicted vs. Normalized Predicted Influences for {model}')
    plt.legend()
    plt.show()

# %%
# multi bar chart with error for mean residue for time step 1, 2 and 3 separately for both average of median - game 1, 2, 3 combined and also separately
# MI v4

# trimmed mean? IQR
